# %% [markdown]
# ### DATA VISUALIZATION W/ SEABORN
#
# Seaborn is a python visualization library based on matplotib that provides a high-level interface for drawing attractive and informatice statisticals graphics. Seaborn helps in creating complex visualizations with just a few lines of code. In this lesson, we will cover the basics of seaboorn, including various types of plots and customizing them

# %%
# !pip install seaborn

# %%
import seaborn as sns

# Basic Plotting w/ Seaborn
tips = sns.load_dataset('tips')
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Create a Scatter Plot

import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("Scatter Plot of Total Bill vs Tips")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Total Bill vs Tips')

# %%
## Line Plot

sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Line Plot of Total Bill by Size")
plt.show()

# %%
## Categorical Plots
## Bar Plot

sns.barplot(x='day',y='total_bill',data=tips)
plt.title("Bar Plot of Total Bill by Day")
plt.show()

# %%
## Box Plot
sns.boxplot(x='day',y='total_bill',data=tips)
plt.title('Boxplot of Total Bill by Day')
plt.show()

# %%
## Violin Plot

sns.violinplot(x='day',y='total_bill',data=tips)
plt.title('Violinplot of Total Bill by Day')
plt.show()

# %%
## Histograms 

sns.histplot(tips['total_bill'],bins=10,kde=True)
plt.title('Histogram of Total Bill by Count')
plt.show()

# %%
## KDE PLOT

sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# Pairplot

sns.pairplot(tips)

# %%
# Heatmap

corr =tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd

sales_df = pd.read_csv('Sales.csv')
sales_df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
## Plot Total Sales by Product
plt.figure(figsize=(10,6))
sns.barplot(x='Product_Category',y='Revenue',data=sales_df,estimator=sum)
plt.title("Total Sales by Product")
plt.xlabel("Product")
plt.ylabel("Total Sales")
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
## Plot Total Sales by Region
plt.figure(figsize=(10,6))
sns.barplot(x='Country',y='Revenue',data=sales_df,estimator=sum)
plt.title("Total Sales by Region")
plt.xlabel("Country")
plt.ylabel("Total Sales")
plt.show()
